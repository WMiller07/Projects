# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.dates as mdates

# %%
df = pd.read_csv('SalesHistory_ItemTypes.csv', header=0)

# %%
df.head()
# Out:
#   BusinessWeek  LocationNo ProductType  count_SalesTransactions  \
# 0          NaN         NaN         NaN                375464922
# 1          NaN         NaN         NaN                      866
# 2          NaN         NaN          $$                    16068
# 3          NaN         NaN        ASTC                     4130
# 4          NaN         NaN        ASTM                    16722
#
#    total_SalesAmount  total_QuantitySold
# 0       1.977034e+09           422708986
# 1       4.473380e+03                 814
# 2       1.769206e+05               16559
# 3       1.338019e+04                4033
# 4       5.892485e+04               16503

# %%
df['BusinessWeek'] = pd.to_datetime(df['BusinessWeek'])

# %%
filter_ChainSales = df['LocationNo'].isna() & ~df['BusinessWeek'].isna()
filter_AllProducts = df['ProductType'].isna()
filter_LowSales = df['total_QuantitySold'] < 100

# %%
df.drop(df[filter_ChainSales & filter_AllProducts & filter_LowSales].index, inplace=True)

# %%
filter_ChainSales = df['LocationNo'].isna() & ~df['BusinessWeek'].isna()
filter_AllProducts = df['ProductType'].isna()
filter_LowSales = df['total_QuantitySold'] < 100

# %%
df[filter_ChainSales & filter_AllProducts]
# Out:
#                     BusinessWeek  LocationNo ProductType  \
# 12888    2010-12-27 00:00:00.000         NaN         NaN
# 17156    2011-01-03 00:00:00.000         NaN         NaN
# 22489    2011-01-10 00:00:00.000         NaN         NaN
# 27723    2011-01-17 00:00:00.000         NaN         NaN
# 32999    2011-01-24 00:00:00.000         NaN         NaN
# ...                          ...         ...         ...
# 3368552  2019-12-02 00:00:00.000         NaN         NaN
# 3376676  2019-12-09 00:00:00.000         NaN         NaN
# 3384951  2019-12-16 00:00:00.000         NaN         NaN
# 3393335  2019-12-23 00:00:00.000         NaN         NaN
# 3401740  2019-12-30 00:00:00.000         NaN         NaN
#
#          count_SalesTransactions  total_SalesAmount  total_QuantitySold
# 12888                     113964          608718.63              136838
# 17156                     789818         4184265.83              964741
# 22489                     696656         3696345.76              870953
# 27723                     766193         4041178.55              956502
# 32999                     745285         3913032.08              933967
# ...                          ...                ...                 ...
# 3368552                   777831         4687517.64              838009
# 3376676                   920537         5827069.18              965305
# 3384951                  1136391         7745011.81             1178811
# 3393335                  1144211         7285375.60             1192277
# 3401740                   367986         2088002.14              389618
#
# [471 rows x 6 columns]

# %%
sns.set_style('whitegrid')
filter_PB = df['ProductType'] == 'PB'
fig, ax = plt.subplots(figsize=(24,6))
ax.plot(df[filter_ChainSales & filter_PB]['BusinessWeek'],
                df[filter_ChainSales & filter_PB]['total_SalesAmount'])
ax.set_yticklabels(['${:0,.0f}'.format(i) for i in ax.get_yticks()])
plt.show()

# %%
sns.set_style('whitegrid')
filter_PB = df['ProductType'].isna()
fig, ax = plt.subplots(figsize=(24,6))
ax.plot(df[filter_ChainSales & filter_PB]['BusinessWeek'],
                df[filter_ChainSales & filter_PB]['total_SalesAmount'])
ax.set_yticklabels(['${:0,.0f}'.format(i) for i in ax.get_yticks()])
plt.show()
